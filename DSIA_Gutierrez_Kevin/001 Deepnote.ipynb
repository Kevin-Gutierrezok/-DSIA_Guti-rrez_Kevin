# %% [markdown]
# # TP01 \- Deepnote Apellido y Nombre

# %% [markdown]
# ¿quién sos? Mi nombre es Kevin Emanuel Gutiérrez
# ¿qué haces? Actualmente me dedico a mi profesión de enfermero
# ¿qué expectativas tenés de la materia? Mis expectativas son las de profundizar mucho mas los conocimientos con respecto a la carrera, esta materia me resulta muy interesante y creo que con el aprendizaje de estas nuevas herramientas me siento muy motivado\.

# %%
print("Mi primer notebook en Deepnote, SALUDOS!")
# Out:
# Mi primer notebook en Deepnote, SALUDOS!

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bd6fa951-a946-406a-8123-57bc80d9b9b2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
