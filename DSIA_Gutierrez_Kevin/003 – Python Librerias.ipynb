# %% [markdown]
# # TP03 – Python Librerías

# %% [markdown]
# Gutiérrez Kevin

# %%
#Ejercicio 1 – Importación de librerías

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

datos = np.array([21,6,94,9,12])
print(datos)

#Ejercicio 2 – Dataset simple con Pandas

import pandas as pd

data = {"estudiante": ["Ana", "Juan", "Carla", "Pedro", "Lucia"],"nota": [8, 6, 9, 5, 7],}
df = pd.DataFrame(data)
print(df)


promedio = df["nota"].mean()
print(f"Promedio de las notas: {promedio}")

nota_maxima = df["nota"].max()
print(f"Nota máxima: {nota_maxima}")

nota_minima = df["nota"].min()
print(f"Nota mínima: {nota_minima}")
# Out:
# [21  6 94  9 12]
#   estudiante  nota
# 0        Ana     8
# 1       Juan     6
# 2      Carla     9
# 3      Pedro     5
# 4      Lucia     7
# Promedio de las notas: 7.0
# Nota máxima: 9
# Nota mínima: 5

# %% [markdown]
# \#Ejercicio 3 – Criterio de selección de herramientas  ¿Qué librería utilizarías para cada una de las siguientes tareas?

# %% [markdown]
# Leer un archivo CSV con datos de encuestas: pandas es ideal para crear el CSV en un DataFrame\.
# Crear un gráfico de distribución de datos
# Realizar un modelo de Machine Learning
# Trabajar con operaciones matemáticas sobre matrices
# Escribir la librería elegida y una breve justificación\.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bd6fa951-a946-406a-8123-57bc80d9b9b2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
