# %% [markdown]
# # TP02 – Introducción a Python

# %% [markdown]
# Gutierrez Kevin

# %%
#Ejercicio 1 – Variables y operaciones
n= "Kevin"
e= 32
ciudad= "CABA"

print("Hola, mi nombre es",n , "tengo",e ,"años y vivo en",ciudad)

a=10
b=2

suma = a+b
print("La suma de a y b es:", suma )
res = a-b
print("La resta de a y b es:", res)
mul = a*b
print("La multiplicación de a y b es:", mul)
div = a/b
print("La división de a y b es:", div)

#Ejercicio 2 – Condicionales
x = int(input( "ingrese su edad:"))
if x >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")

#Ejercicio 3 – Listas y bucles

Lista = [10, 15, 20, 25, 30]
print("Los numeros de la lista son:")
for numero in Lista:
    print(numero)
suma_total = sum(Lista)
promedio = suma_total / len(Lista)
print("La suma de los numeros es:", suma_total)
print("El promedio de los numeros es:", promedio)
# Out:
# Hola, mi nombre es Kevin tengo 32 años y vivo en CABA
# La suma de a y b es: 12
# La resta de a y b es: 8
# La multiplicación de a y b es: 20
# La división de a y b es: 5.0
# Eres menor de edad
# Los numeros de la lista son:
# 10
# 15
# 20
# 25
# 30
# La suma de los numeros es: 100
# El promedio de los numeros es: 20.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=60d0f1b1-61f8-48fc-8950-fe65c4f26ed9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
